# %%
import cv2, os
import numpy as np
import matplotlib.image as mpimg
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
#from keras.models import Sequential
#from keras.optimizers import Adam
#from keras.callbacks import ModelCheckpoint
#from keras.layers import Lambda, Conv2D, MaxPooling2D, Dropout, Dense, Flatten
import torch
import torch.nn
from torch.optim import Adam
#from utilis import INPUT_SHAPE, batch_generator
import argparse
import os



IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS = 66, 200, 3
INPUT_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)


def load_image(data_dir, image_file):
    """
    Load RGB images from a file
    """

    return mpimg.imread(image_file)


def crop(image):
    """
    Crop the image (removing the sky at the top and the car front at the bottom)
    """
    return image[60:-25, :, :] # remove the sky and the car front


def resize(image):
    """
    Resize the image to the input shape used by the network model
    """
    return cv2.resize(image, (IMAGE_WIDTH, IMAGE_HEIGHT), cv2.INTER_AREA)


def rgb2yuv(image):
    """
    Convert the image from RGB to YUV (This is what the NVIDIA model does)
    """
    return cv2.cvtColor(image, cv2.COLOR_RGB2YUV)


def preprocess(image):
    """
    Combine all preprocess functions into one
    """
    image = crop(image)
    image = resize(image)
    image = rgb2yuv(image)
    return image


def choose_image(data_dir, center, left, right, steering_angle):
    """
    Randomly choose an image from the center, left or right, and adjust
    the steering angle.
    """
    choice = np.random.choice(3)
    if choice == 0:
        return load_image(data_dir, left), steering_angle + 0.2
    elif choice == 1:
        return load_image(data_dir, right), steering_angle - 0.2
    return load_image(data_dir, center), steering_angle


def random_flip(image, steering_angle):
    """
    Randomly flipt the image left <-> right, and adjust the steering angle.
    """
    if np.random.rand() < 0.5:
        image = cv2.flip(image, 1)
        steering_angle = -steering_angle
    return image, steering_angle


def random_translate(image, steering_angle, range_x, range_y):
    """
    Randomly shift the image virtially and horizontally (translation).
    """
    trans_x = range_x * (np.random.rand() - 0.5)
    trans_y = range_y * (np.random.rand() - 0.5)
    steering_angle += trans_x * 0.002
    trans_m = np.float32([[1, 0, trans_x], [0, 1, trans_y]])
    height, width = image.shape[:2]
    image = cv2.warpAffine(image, trans_m, (width, height))
    return image, steering_angle


# def random_shadow(image):
#     """
#     Generates and adds random shadow
#     """
#     # (x1, y1) and (x2, y2) forms a line
#     # xm, ym gives all the locations of the image
#     x1, y1 = IMAGE_WIDTH * np.random.rand(), 0
#     x2, y2 = IMAGE_WIDTH * np.random.rand(), IMAGE_HEIGHT
#     xm, ym = np.mgrid[0:IMAGE_HEIGHT, 0:IMAGE_WIDTH]
#
#     # mathematically speaking, we want to set 1 below the line and zero otherwise
#     # Our coordinate is up side down.  So, the above the line:
#     # (ym-y1)/(xm-x1) > (y2-y1)/(x2-x1)
#     # as x2 == x1 causes zero-division problem, we'll write it in the below form:
#     # (ym-y1)*(x2-x1) - (y2-y1)*(xm-x1) > 0
#     mask = np.zeros_like(image[:, :, 1])
#     mask[(ym - y1) * (x2 - x1) - (y2 - y1) * (xm - x1) > 0] = 1
#
#     # choose which side should have shadow and adjust saturation
#     cond = mask == np.random.randint(2)
#     s_ratio = np.random.uniform(low=0.2, high=0.5)
#
#     # adjust Saturation in HLS(Hue, Light, Saturation)
#     hls = cv2.cvtColor(image, cv2.COLOR_RGB2HLS)
#     hls[:, :, 1][cond] = hls[:, :, 1][cond] * s_ratio
#     return cv2.cvtColor(hls, cv2.COLOR_HLS2RGB)


def random_brightness(image):
    """
    Randomly adjust brightness of the image.
    """
    # HSV (Hue, Saturation, Value) is also called HSB ('B' for Brightness).
    hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
    ratio = 1.0 + 0.4 * (np.random.rand() - 0.5)
    hsv[:,:,2] =  hsv[:,:,2] * ratio
    return cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)


def augument(data_dir, center, left, right, steering_angle, range_x=100, range_y=10):
    """
    Generate an augumented image and adjust steering angle.
    (The steering angle is associated with the center image)
    """
    image, steering_angle = choose_image(data_dir, center, left, right, steering_angle)
    image, steering_angle = random_flip(image, steering_angle)
    image, steering_angle = random_translate(image, steering_angle, range_x, range_y)
    #image = random_shadow(image)
    image = random_brightness(image)
    return image, steering_angle


def batch_generator(data_dir, image_paths, steering_angles, batch_size, is_training):
    """
    Generate training image give image paths and associated steering angles
    """
    images = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS])
    steers = np.empty(batch_size)
    # while True:
    i = 0
    for index in np.random.permutation(image_paths.shape[0]):
        center, left, right = image_paths[index]
        steering_angle = steering_angles[index]
        # argumentation
        if is_training and np.random.rand() < 0.6:
            image, steering_angle = augument(data_dir, center, left, right, steering_angle)
        else:
            image = load_image(data_dir, center)
        # add the image and steering angle to the batch
        images[i % batch_size] = preprocess(image)
        steers[i % batch_size] = steering_angle
        i += 1
        if i % batch_size == 0:
            yield images, steers
            images = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS])
            steers = np.empty(batch_size)

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install pyunpack
# !pip install patool
from pyunpack import Archive
Archive('Location of the rar file').extractall('Location where you want to have the folder')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
x = pd.read_csv('/content/data.csv')
x.head()
# Out:
#    Unnamed: 0  ...     break
# 0           0  ...  4.253256
# 1           1  ...  4.951154
# 2           2  ...  5.878301
# 3           3  ...  6.798285
# 4           4  ...  7.483586
#
# [5 rows x 8 columns]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5304 entries, 0 to 5303
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5304 non-null   int64
#  1   center      5304 non-null   object
#  2   left        5304 non-null   object
#  3   right       5304 non-null   object
#  4   steering    5304 non-null   float64
#  5   speed       5304 non-null   int64
#  6   throttle    5304 non-null   int64
#  7   break       5304 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 331.6+ KB

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
path = x['center'][533]
print(path)
image = mpimg.imread(path)
plt.imshow(image)
plt.show()
# Out:
# /content/IMG/center_2021_05_15_04_32_49_137.jpg

# %%
np.random.seed(0)
training_loss = []
validation_loss = []

def load_data(args):
    """
    Load training data and split it into training and validation set
    """
    #print(os.path.join(args.data_dir,'driving_log.csv'))
    data_df = pd.read_csv('/content/data.csv')

    X = data_df[['center','left','right']].values
    y = data_df['steering'].values
    # X = X[:2000]
    # y = y[:2000]
    print(X.shape)
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=args.test_size, random_state=0)
    #X_train = X_train / 127.5 - 1.0
    #X_valid = X_valid / 127.5 - 1.0
    return X_train, X_valid, y_train, y_valid


def build_model(args):
    """
    Modified NVIDIA model
    """
    model = torch.nn.Sequential(
        torch.nn.Conv2d(in_channels = 3, out_channels = 24,kernel_size = (5,5), stride = (2,2)),
        torch.nn.ELU(),
        torch.nn.Conv2d(in_channels=24, out_channels=36, kernel_size=(5, 5), stride=(2, 2)),
        torch.nn.ELU(),
        torch.nn.Conv2d(in_channels=36, out_channels=48, kernel_size=(5, 5), stride=(2, 2)),
        torch.nn.ELU(),
        torch.nn.Conv2d(in_channels=48, out_channels=64, kernel_size=(3,3), stride=(1, 1)),
        torch.nn.ELU(),
        torch.nn.Conv2d(in_channels=64, out_channels=64, kernel_size=(3,3), stride=(1, 1)),
        torch.nn.ELU(),
        torch.nn.Dropout(p=args.keep_prob, inplace=True),
        torch.nn.Flatten(),
        torch.nn.Linear(in_features = 1152, out_features = 100,bias = True),
        torch.nn.ELU(),
        torch.nn.Linear(in_features = 100,out_features = 50,bias = True),
        torch.nn.ELU(),
        torch.nn.Linear(in_features = 50,out_features = 10,bias = True),
        torch.nn.ELU(),
        torch.nn.Linear(in_features = 10,out_features = 1,bias = True)
    )
    #model = Sequential()
    #model.add(Lambda(lambda x: x / 127.5 - 1.0, input_shape=INPUT_SHAPE))
    #model.add(Conv2D(24, 5, 5, activation='elu', subsample=(2, 2)))
    #model.add(Conv2D(36, 5, 5, activation='elu', subsample=(2, 2)))
    #model.add(Conv2D(48, 5, 5, activation='elu', subsample=(2, 2)))
    #model.add(Conv2D(64, 3, 3, activation='elu'))
    #model.add(Conv2D(64, 3, 3, activation='elu'))
    #model.add(Dropout(args.keep_prob))
    #model.add(Flatten())
    #model.add(Dense(100, activation='elu'))
    #model.add(Dense(50, activation='elu'))
    #model.add(Dense(10, activation='elu'))
    #model.add(Dense(1))
    #model.summary()

    return model


def train_model(model, args, X_train, X_valid, y_train, y_valid):
    """
    Train the model
    """
    criterion = torch.nn.MSELoss()

    optimizer = Adam(model.parameters(),lr = args.learning_rate)

    
    for epoch in range(args.nb_epoch):
        running_loss = 0
        total_loss_valid = 0
        model.train()
        total_loss = 0
        i = 0
        print('Epoch : {}'.format(epoch + 1))
        print('XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX')
        for imgs,steers in batch_generator(args.data_dir, X_train, y_train, args.batch_size, True):

            shape_imgs = imgs.shape
            imgs = imgs.reshape(shape_imgs[0],shape_imgs[3],shape_imgs[1],shape_imgs[2])
            imgs = torch.FloatTensor(imgs)
            steers = steers.reshape(args.batch_size,1)
            steers = torch.FloatTensor(steers)
            optimizer.zero_grad()

            outputs = model(imgs)
            loss = criterion(outputs, steers)


            loss.backward()
            optimizer.step()
            i = i + 1
            running_loss += loss.item()
            del loss

            # print statistics
            if i % 5 == 0:  # print every 5 mini-batches
                print('The training loss: %.6f after %d' % (running_loss / (i),i))

        running_loss = running_loss / (X_train.shape[0]  / 40)



        model.eval()


        j = 0
        for imgs, steers in batch_generator(args.data_dir, X_valid, y_valid, args.batch_size, False):

            shape_imgs = imgs.shape
            imgs = imgs.reshape(shape_imgs[0], shape_imgs[3], shape_imgs[1], shape_imgs[2])
            imgs  = torch.FloatTensor(imgs)
            steers = steers.reshape(args.batch_size, 1)
            steers = torch.FloatTensor(steers)
            optimizer.zero_grad()

            j = j + 1
            outputs = model(imgs)
            loss = criterion(outputs, steers)
            total_loss_valid = total_loss_valid + loss.item()
            if j % 5 == 0:  # print every 5 mini-batches
                print('The Validation loss: %.6f after %d' % (total_loss_valid / (j), j))

        total_loss_valid = total_loss_valid / (X_valid.shape[0] / 40)

        training_loss.append(running_loss)

        print('The training loss after epoch{} is {}'.format(epoch,(running_loss)))
        validation_loss.append(total_loss_valid)
        print('The validation loss after epoch{} is {}'.format(epoch, total_loss_valid))



def s2b(s):
    """
    Converts a string to boolean value
    """
    s = s.lower()
    return s == 'true' or s == 'yes' or s == 'y' or s == '1'


def main():
    """
    Load train/validation data set and train the model
    """
    parser = argparse.ArgumentParser(description='Behavioral Cloning Training Program')
    parser.add_argument('-d', help='data directory', dest='data_dir', type=str, default='/content/')
    parser.add_argument('-t', help='test size fraction', dest='test_size', type=float, default=0.2)
    parser.add_argument('-k', help='drop out probability', dest='keep_prob', type=float, default=0.5)
    parser.add_argument('-n', help='number of epochs', dest='nb_epoch', type=int, default=50)
    parser.add_argument('-s', help='samples per epoch', dest='samples_per_epoch', type=int, default=20000)
    parser.add_argument('-b', help='batch size', dest='batch_size', type=int, default=40)
    parser.add_argument('-o', help='save best models only', dest='save_best_only', type=s2b, default='true')
    parser.add_argument('-l', help='learning rate', dest='learning_rate', type=float, default=1.0e-4)
    args = parser.parse_args(args = [])

    print('-' * 30)
    print('Parameters')
    print('-' * 30)
    for key, value in vars(args).items():
        print('{:<20} := {}'.format(key, value))
    print('-' * 30)

    data = load_data(args)
    model = build_model(args)
    train_model(model, args, *data)



    torch.save(model, 'model.pth')
if __name__ == '__main__':
    main()
# Out:
# ------------------------------
# Parameters
# ------------------------------
# data_dir             := /content/
# test_size            := 0.2
# keep_prob            := 0.5
# nb_epoch             := 50
# samples_per_epoch    := 20000
# batch_size           := 40
# save_best_only       := True
# learning_rate        := 0.0001
# ------------------------------
# (5304, 3)
# Epoch : 1
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.063963 after 5
# The training loss: 0.055125 after 10
# The training loss: 0.056279 after 15
# The training loss: 0.052096 after 20
# The training loss: 0.051256 after 25
# The training loss: 0.051031 after 30
# The training loss: 0.048358 after 35
# The training loss: 0.048336 after 40
# The training loss: 0.048080 after 45
# The training loss: 0.046538 after 50
# The training loss: 0.045823 after 55
# The training loss: 0.044797 after 60
# The training loss: 0.044132 after 65
# The training loss: 0.043258 after 70
# The training loss: 0.042038 after 75
# The training loss: 0.041293 after 80
# The training loss: 0.041066 after 85
# The training loss: 0.040727 after 90
# The training loss: 0.040476 after 95
# The training loss: 0.040196 after 100
# The training loss: 0.039456 after 105
# The Validation loss: 0.014967 after 5
# The Validation loss: 0.014345 after 10
# The Validation loss: 0.014546 after 15
# The Validation loss: 0.014930 after 20
# The Validation loss: 0.016980 after 25
# The training loss after epoch0 is 0.03921358848542446
# The validation loss after epoch0 is 0.016527093418511326
# Epoch : 2
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.032201 after 5
# The training loss: 0.031947 after 10
# The training loss: 0.029645 after 15
# The training loss: 0.031738 after 20
# The training loss: 0.032197 after 25
# The training loss: 0.034433 after 30
# The training loss: 0.034173 after 35
# The training loss: 0.034239 after 40
# The training loss: 0.033248 after 45
# The training loss: 0.032668 after 50
# The training loss: 0.032800 after 55
# The training loss: 0.032583 after 60
# The training loss: 0.032506 after 65
# The training loss: 0.033032 after 70
# The training loss: 0.033459 after 75
# The training loss: 0.033432 after 80
# The training loss: 0.033493 after 85
# The training loss: 0.033322 after 90
# The training loss: 0.033377 after 95
# The training loss: 0.033807 after 100
# The training loss: 0.034024 after 105
# The Validation loss: 0.016798 after 5
# The Validation loss: 0.016578 after 10
# The Validation loss: 0.016089 after 15
# The Validation loss: 0.015516 after 20
# The Validation loss: 0.015669 after 25
# The training loss after epoch1 is 0.03392851644358263
# The validation loss after epoch1 is 0.015842757599461653
# Epoch : 3
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.035425 after 5
# The training loss: 0.034597 after 10
# The training loss: 0.032770 after 15
# The training loss: 0.036526 after 20
# The training loss: 0.036675 after 25
# The training loss: 0.036064 after 30
# The training loss: 0.035079 after 35
# The training loss: 0.034455 after 40
# The training loss: 0.033686 after 45
# The training loss: 0.033879 after 50
# The training loss: 0.033639 after 55
# The training loss: 0.033540 after 60
# The training loss: 0.033172 after 65
# The training loss: 0.033726 after 70
# The training loss: 0.033927 after 75
# The training loss: 0.033641 after 80
# The training loss: 0.033384 after 85
# The training loss: 0.033497 after 90
# The training loss: 0.033436 after 95
# The training loss: 0.033695 after 100
# The training loss: 0.033590 after 105
# The Validation loss: 0.021440 after 5
# The Validation loss: 0.020411 after 10
# The Validation loss: 0.018599 after 15
# The Validation loss: 0.017833 after 20
# The Validation loss: 0.017334 after 25
# The training loss after epoch2 is 0.03363511034081405
# The validation loss after epoch2 is 0.01671678682439851
# Epoch : 4
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.034051 after 5
# The training loss: 0.033037 after 10
# The training loss: 0.032659 after 15
# The training loss: 0.031138 after 20
# The training loss: 0.031887 after 25
# The training loss: 0.031299 after 30
# The training loss: 0.032231 after 35
# The training loss: 0.033295 after 40
# The training loss: 0.032995 after 45
# The training loss: 0.032873 after 50
# The training loss: 0.032140 after 55
# The training loss: 0.031939 after 60
# The training loss: 0.032445 after 65
# The training loss: 0.032589 after 70
# The training loss: 0.032939 after 75
# The training loss: 0.032767 after 80
# The training loss: 0.032772 after 85
# The training loss: 0.032827 after 90
# The training loss: 0.032348 after 95
# The training loss: 0.032329 after 100
# The training loss: 0.032431 after 105
# The Validation loss: 0.012026 after 5
# The Validation loss: 0.013455 after 10
# The Validation loss: 0.016454 after 15
# The Validation loss: 0.016476 after 20
# The Validation loss: 0.015855 after 25
# The training loss after epoch3 is 0.032332675786561176
# The validation loss after epoch3 is 0.015428346352656983
# Epoch : 5
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.036321 after 5
# The training loss: 0.033948 after 10
# The training loss: 0.037315 after 15
# The training loss: 0.035753 after 20
# The training loss: 0.036026 after 25
# The training loss: 0.035262 after 30
# The training loss: 0.036335 after 35
# The training loss: 0.035279 after 40
# The training loss: 0.035861 after 45
# The training loss: 0.035919 after 50
# The training loss: 0.035498 after 55
# The training loss: 0.034858 after 60
# The training loss: 0.034136 after 65
# The training loss: 0.034272 after 70
# The training loss: 0.033967 after 75
# The training loss: 0.034450 after 80
# The training loss: 0.034425 after 85
# The training loss: 0.034536 after 90
# The training loss: 0.034220 after 95
# The training loss: 0.034254 after 100
# The training loss: 0.033919 after 105
# The Validation loss: 0.017820 after 5
# The Validation loss: 0.015029 after 10
# The Validation loss: 0.015365 after 15
# The Validation loss: 0.015370 after 20
# The Validation loss: 0.015166 after 25
# The training loss after epoch4 is 0.03377676400835155
# The validation loss after epoch4 is 0.015302051146647259
# Epoch : 6
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.040023 after 5
# The training loss: 0.040467 after 10
# The training loss: 0.037992 after 15
# The training loss: 0.034578 after 20
# The training loss: 0.033106 after 25
# The training loss: 0.033501 after 30
# The training loss: 0.032109 after 35
# The training loss: 0.031666 after 40
# The training loss: 0.033008 after 45
# The training loss: 0.032775 after 50
# The training loss: 0.032467 after 55
# The training loss: 0.032564 after 60
# The training loss: 0.031655 after 65
# The training loss: 0.031329 after 70
# The training loss: 0.030961 after 75
# The training loss: 0.030483 after 80
# The training loss: 0.030662 after 85
# The training loss: 0.030709 after 90
# The training loss: 0.030892 after 95
# The training loss: 0.030675 after 100
# The training loss: 0.030347 after 105
# The Validation loss: 0.009840 after 5
# The Validation loss: 0.012986 after 10
# The Validation loss: 0.012788 after 15
# The Validation loss: 0.013958 after 20
# The Validation loss: 0.014994 after 25
# The training loss after epoch5 is 0.030281519920736615
# The validation loss after epoch5 is 0.014758350382033212
# Epoch : 7
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.023974 after 5
# The training loss: 0.026687 after 10
# The training loss: 0.028183 after 15
# The training loss: 0.027969 after 20
# The training loss: 0.027733 after 25
# The training loss: 0.029494 after 30
# The training loss: 0.029477 after 35
# The training loss: 0.029742 after 40
# The training loss: 0.029717 after 45
# The training loss: 0.029858 after 50
# The training loss: 0.029126 after 55
# The training loss: 0.029126 after 60
# The training loss: 0.030218 after 65
# The training loss: 0.029932 after 70
# The training loss: 0.029821 after 75
# The training loss: 0.030124 after 80
# The training loss: 0.030054 after 85
# The training loss: 0.029902 after 90
# The training loss: 0.029673 after 95
# The training loss: 0.029610 after 100
# The training loss: 0.029611 after 105
# The Validation loss: 0.015154 after 5
# The Validation loss: 0.015285 after 10
# The Validation loss: 0.014921 after 15
# The Validation loss: 0.015565 after 20
# The Validation loss: 0.014701 after 25
# The training loss after epoch6 is 0.029678628069877398
# The validation loss after epoch6 is 0.01428691626409671
# Epoch : 8
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.027588 after 5
# The training loss: 0.028922 after 10
# The training loss: 0.032808 after 15
# The training loss: 0.031670 after 20
# The training loss: 0.030073 after 25
# The training loss: 0.029805 after 30
# The training loss: 0.028878 after 35
# The training loss: 0.028364 after 40
# The training loss: 0.028623 after 45
# The training loss: 0.028221 after 50
# The training loss: 0.029060 after 55
# The training loss: 0.028765 after 60
# The training loss: 0.028503 after 65
# The training loss: 0.028199 after 70
# The training loss: 0.028042 after 75
# The training loss: 0.028229 after 80
# The training loss: 0.028072 after 85
# The training loss: 0.028275 after 90
# The training loss: 0.028353 after 95
# The training loss: 0.028366 after 100
# The training loss: 0.028660 after 105
# The Validation loss: 0.013972 after 5
# The Validation loss: 0.012876 after 10
# The Validation loss: 0.014330 after 15
# The Validation loss: 0.014821 after 20
# The Validation loss: 0.014831 after 25
# The training loss after epoch7 is 0.02873176879585562
# The validation loss after epoch7 is 0.014413049151378348
# Epoch : 9
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.021246 after 5
# The training loss: 0.025712 after 10
# The training loss: 0.027801 after 15
# The training loss: 0.029319 after 20
# The training loss: 0.028515 after 25
# The training loss: 0.027176 after 30
# The training loss: 0.026857 after 35
# The training loss: 0.026949 after 40
# The training loss: 0.026890 after 45
# The training loss: 0.027103 after 50
# The training loss: 0.026752 after 55
# The training loss: 0.026537 after 60
# The training loss: 0.027367 after 65
# The training loss: 0.027838 after 70
# The training loss: 0.027944 after 75
# The training loss: 0.027921 after 80
# The training loss: 0.028232 after 85
# The training loss: 0.028213 after 90
# The training loss: 0.027764 after 95
# The training loss: 0.027720 after 100
# The training loss: 0.027772 after 105
# The Validation loss: 0.009593 after 5
# The Validation loss: 0.012404 after 10
# The Validation loss: 0.012353 after 15
# The Validation loss: 0.012902 after 20
# The Validation loss: 0.013204 after 25
# The training loss after epoch8 is 0.027944871854197716
# The validation loss after epoch8 is 0.01389906287867432
# Epoch : 10
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.034013 after 5
# The training loss: 0.031311 after 10
# The training loss: 0.031314 after 15
# The training loss: 0.031205 after 20
# The training loss: 0.029397 after 25
# The training loss: 0.028945 after 30
# The training loss: 0.027983 after 35
# The training loss: 0.028460 after 40
# The training loss: 0.028711 after 45
# The training loss: 0.028832 after 50
# The training loss: 0.029281 after 55
# The training loss: 0.029301 after 60
# The training loss: 0.028690 after 65
# The training loss: 0.028508 after 70
# The training loss: 0.028225 after 75
# The training loss: 0.027959 after 80
# The training loss: 0.028091 after 85
# The training loss: 0.028498 after 90
# The training loss: 0.028211 after 95
# The training loss: 0.028141 after 100
# The training loss: 0.028091 after 105
# The Validation loss: 0.008385 after 5
# The Validation loss: 0.011971 after 10
# The Validation loss: 0.013244 after 15
# The Validation loss: 0.013976 after 20
# The Validation loss: 0.013449 after 25
# The training loss after epoch9 is 0.02794330991012657
# The validation loss after epoch9 is 0.01400247811358229
# Epoch : 11
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.027280 after 5
# The training loss: 0.026034 after 10
# The training loss: 0.025975 after 15
# The training loss: 0.025379 after 20
# The training loss: 0.027377 after 25
# The training loss: 0.028769 after 30
# The training loss: 0.028842 after 35
# The training loss: 0.029585 after 40
# The training loss: 0.030103 after 45
# The training loss: 0.029408 after 50
# The training loss: 0.029217 after 55
# The training loss: 0.028965 after 60
# The training loss: 0.028956 after 65
# The training loss: 0.028729 after 70
# The training loss: 0.028318 after 75
# The training loss: 0.028225 after 80
# The training loss: 0.028022 after 85
# The training loss: 0.028252 after 90
# The training loss: 0.028120 after 95
# The training loss: 0.028047 after 100
# The training loss: 0.027929 after 105
# The Validation loss: 0.011137 after 5
# The Validation loss: 0.012625 after 10
# The Validation loss: 0.012881 after 15
# The Validation loss: 0.013378 after 20
# The Validation loss: 0.013654 after 25
# The training loss after epoch10 is 0.027925018462585778
# The validation loss after epoch10 is 0.013354143705377032
# Epoch : 12
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.019737 after 5
# The training loss: 0.023831 after 10
# The training loss: 0.023831 after 15
# The training loss: 0.023886 after 20
# The training loss: 0.024711 after 25
# The training loss: 0.024514 after 30
# The training loss: 0.024908 after 35
# The training loss: 0.025599 after 40
# The training loss: 0.025765 after 45
# The training loss: 0.025684 after 50
# The training loss: 0.026046 after 55
# The training loss: 0.026010 after 60
# The training loss: 0.026074 after 65
# The training loss: 0.026206 after 70
# The training loss: 0.027059 after 75
# The training loss: 0.026966 after 80
# The training loss: 0.027261 after 85
# The training loss: 0.027031 after 90
# The training loss: 0.026780 after 95
# The training loss: 0.027237 after 100
# The training loss: 0.027544 after 105
# The Validation loss: 0.012307 after 5
# The Validation loss: 0.011970 after 10
# The Validation loss: 0.011001 after 15
# The Validation loss: 0.012298 after 20
# The Validation loss: 0.013465 after 25
# The training loss after epoch11 is 0.02743529467974073
# The validation loss after epoch11 is 0.013082261749391394
# Epoch : 13
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.025668 after 5
# The training loss: 0.027490 after 10
# The training loss: 0.027104 after 15
# The training loss: 0.026503 after 20
# The training loss: 0.026400 after 25
# The training loss: 0.025871 after 30
# The training loss: 0.025898 after 35
# The training loss: 0.025680 after 40
# The training loss: 0.024890 after 45
# The training loss: 0.024586 after 50
# The training loss: 0.024847 after 55
# The training loss: 0.025278 after 60
# The training loss: 0.024976 after 65
# The training loss: 0.024690 after 70
# The training loss: 0.024562 after 75
# The training loss: 0.025309 after 80
# The training loss: 0.025363 after 85
# The training loss: 0.025783 after 90
# The training loss: 0.025848 after 95
# The training loss: 0.026136 after 100
# The training loss: 0.026570 after 105
# The Validation loss: 0.012423 after 5
# The Validation loss: 0.015135 after 10
# The Validation loss: 0.014370 after 15
# The Validation loss: 0.013725 after 20
# The Validation loss: 0.013642 after 25
# The training loss after epoch12 is 0.026612938057974544
# The validation loss after epoch12 is 0.013472648700883544
# Epoch : 14
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.024998 after 5
# The training loss: 0.025698 after 10
# The training loss: 0.025060 after 15
# The training loss: 0.026160 after 20
# The training loss: 0.025561 after 25
# The training loss: 0.026481 after 30
# The training loss: 0.026101 after 35
# The training loss: 0.027638 after 40
# The training loss: 0.027094 after 45
# The training loss: 0.027347 after 50
# The training loss: 0.027250 after 55
# The training loss: 0.027688 after 60
# The training loss: 0.027829 after 65
# The training loss: 0.027724 after 70
# The training loss: 0.027564 after 75
# The training loss: 0.027732 after 80
# The training loss: 0.027653 after 85
# The training loss: 0.027426 after 90
# The training loss: 0.027530 after 95
# The training loss: 0.027226 after 100
# The training loss: 0.026795 after 105
# The Validation loss: 0.013471 after 5
# The Validation loss: 0.011995 after 10
# The Validation loss: 0.012398 after 15
# The Validation loss: 0.012395 after 20
# The Validation loss: 0.012684 after 25
# The training loss after epoch13 is 0.026684725227331795
# The validation loss after epoch13 is 0.012962786264851003
# Epoch : 15
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.023353 after 5
# The training loss: 0.025431 after 10
# The training loss: 0.026192 after 15
# The training loss: 0.024929 after 20
# The training loss: 0.024904 after 25
# The training loss: 0.025120 after 30
# The training loss: 0.025396 after 35
# The training loss: 0.024393 after 40
# The training loss: 0.024980 after 45
# The training loss: 0.024626 after 50
# The training loss: 0.025071 after 55
# The training loss: 0.025641 after 60
# The training loss: 0.025730 after 65
# The training loss: 0.026128 after 70
# The training loss: 0.025968 after 75
# The training loss: 0.025821 after 80
# The training loss: 0.025647 after 85
# The training loss: 0.025544 after 90
# The training loss: 0.025515 after 95
# The training loss: 0.025802 after 100
# The training loss: 0.025674 after 105
# The Validation loss: 0.010420 after 5
# The Validation loss: 0.012069 after 10
# The Validation loss: 0.013466 after 15
# The Validation loss: 0.012822 after 20
# The Validation loss: 0.013104 after 25
# The training loss after epoch14 is 0.02569044320096729
# The validation loss after epoch14 is 0.012703136568160467
# Epoch : 16
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.020355 after 5
# The training loss: 0.026838 after 10
# The training loss: 0.027281 after 15
# The training loss: 0.026163 after 20
# The training loss: 0.025615 after 25
# The training loss: 0.024762 after 30
# The training loss: 0.025909 after 35
# The training loss: 0.025627 after 40
# The training loss: 0.025504 after 45
# The training loss: 0.025323 after 50
# The training loss: 0.025762 after 55
# The training loss: 0.026062 after 60
# The training loss: 0.026280 after 65
# The training loss: 0.026326 after 70
# The training loss: 0.026431 after 75
# The training loss: 0.026076 after 80
# The training loss: 0.026171 after 85
# The training loss: 0.026090 after 90
# The training loss: 0.025715 after 95
# The training loss: 0.025609 after 100
# The training loss: 0.025389 after 105
# The Validation loss: 0.014705 after 5
# The Validation loss: 0.015127 after 10
# The Validation loss: 0.013525 after 15
# The Validation loss: 0.013037 after 20
# The Validation loss: 0.012992 after 25
# The training loss after epoch15 is 0.02551344189298566
# The validation loss after epoch15 is 0.01270504659577207
# Epoch : 17
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.024047 after 5
# The training loss: 0.028849 after 10
# The training loss: 0.029064 after 15
# The training loss: 0.027252 after 20
# The training loss: 0.026133 after 25
# The training loss: 0.026390 after 30
# The training loss: 0.026316 after 35
# The training loss: 0.026445 after 40
# The training loss: 0.026523 after 45
# The training loss: 0.026833 after 50
# The training loss: 0.026802 after 55
# The training loss: 0.026315 after 60
# The training loss: 0.026120 after 65
# The training loss: 0.026061 after 70
# The training loss: 0.026230 after 75
# The training loss: 0.026527 after 80
# The training loss: 0.026329 after 85
# The training loss: 0.026134 after 90
# The training loss: 0.025956 after 95
# The training loss: 0.026268 after 100
# The training loss: 0.026118 after 105
# The Validation loss: 0.015655 after 5
# The Validation loss: 0.016109 after 10
# The Validation loss: 0.015189 after 15
# The Validation loss: 0.014351 after 20
# The Validation loss: 0.013643 after 25
# The training loss after epoch16 is 0.02604001889370984
# The validation loss after epoch16 is 0.013351252023393989
# Epoch : 18
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.026251 after 5
# The training loss: 0.027369 after 10
# The training loss: 0.029166 after 15
# The training loss: 0.028071 after 20
# The training loss: 0.028808 after 25
# The training loss: 0.029123 after 30
# The training loss: 0.028608 after 35
# The training loss: 0.028378 after 40
# The training loss: 0.028809 after 45
# The training loss: 0.028152 after 50
# The training loss: 0.028232 after 55
# The training loss: 0.027770 after 60
# The training loss: 0.027373 after 65
# The training loss: 0.027200 after 70
# The training loss: 0.027110 after 75
# The training loss: 0.027126 after 80
# The training loss: 0.026618 after 85
# The training loss: 0.026361 after 90
# The training loss: 0.026421 after 95
# The training loss: 0.026268 after 100
# The training loss: 0.025824 after 105
# The Validation loss: 0.017331 after 5
# The Validation loss: 0.014538 after 10
# The Validation loss: 0.013023 after 15
# The Validation loss: 0.012575 after 20
# The Validation loss: 0.012779 after 25
# The training loss after epoch17 is 0.025927801586857892
# The validation loss after epoch17 is 0.012494005635029634
# Epoch : 19
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.021515 after 5
# The training loss: 0.022495 after 10
# The training loss: 0.021470 after 15
# The training loss: 0.022801 after 20
# The training loss: 0.023704 after 25
# The training loss: 0.024560 after 30
# The training loss: 0.025276 after 35
# The training loss: 0.024615 after 40
# The training loss: 0.024613 after 45
# The training loss: 0.024448 after 50
# The training loss: 0.024726 after 55
# The training loss: 0.024399 after 60
# The training loss: 0.024590 after 65
# The training loss: 0.024668 after 70
# The training loss: 0.024971 after 75
# The training loss: 0.025212 after 80
# The training loss: 0.025261 after 85
# The training loss: 0.025126 after 90
# The training loss: 0.025163 after 95
# The training loss: 0.025145 after 100
# The training loss: 0.025152 after 105
# The Validation loss: 0.013038 after 5
# The Validation loss: 0.011639 after 10
# The Validation loss: 0.011926 after 15
# The Validation loss: 0.012549 after 20
# The Validation loss: 0.012402 after 25
# The training loss after epoch18 is 0.02506875321743147
# The validation loss after epoch18 is 0.01266485729678749
# Epoch : 20
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.023249 after 5
# The training loss: 0.023780 after 10
# The training loss: 0.025412 after 15
# The training loss: 0.024349 after 20
# The training loss: 0.025838 after 25
# The training loss: 0.025914 after 30
# The training loss: 0.025273 after 35
# The training loss: 0.024734 after 40
# The training loss: 0.024645 after 45
# The training loss: 0.024823 after 50
# The training loss: 0.024317 after 55
# The training loss: 0.024259 after 60
# The training loss: 0.025161 after 65
# The training loss: 0.024784 after 70
# The training loss: 0.024562 after 75
# The training loss: 0.024606 after 80
# The training loss: 0.024991 after 85
# The training loss: 0.024894 after 90
# The training loss: 0.025120 after 95
# The training loss: 0.024958 after 100
# The training loss: 0.024995 after 105
# The Validation loss: 0.011312 after 5
# The Validation loss: 0.012255 after 10
# The Validation loss: 0.013730 after 15
# The Validation loss: 0.014174 after 20
# The Validation loss: 0.014002 after 25
# The training loss after epoch19 is 0.025206060920743876
# The validation loss after epoch19 is 0.013605288592405076
# Epoch : 21
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.020583 after 5
# The training loss: 0.023943 after 10
# The training loss: 0.021902 after 15
# The training loss: 0.022287 after 20
# The training loss: 0.023260 after 25
# The training loss: 0.023357 after 30
# The training loss: 0.024206 after 35
# The training loss: 0.024187 after 40
# The training loss: 0.023834 after 45
# The training loss: 0.024328 after 50
# The training loss: 0.024746 after 55
# The training loss: 0.024626 after 60
# The training loss: 0.024479 after 65
# The training loss: 0.024702 after 70
# The training loss: 0.024257 after 75
# The training loss: 0.024690 after 80
# The training loss: 0.025039 after 85
# The training loss: 0.025110 after 90
# The training loss: 0.024901 after 95
# The training loss: 0.024879 after 100
# The training loss: 0.024749 after 105
# The Validation loss: 0.012730 after 5
# The Validation loss: 0.014046 after 10
# The Validation loss: 0.012776 after 15
# The Validation loss: 0.013664 after 20
# The Validation loss: 0.013032 after 25
# The training loss after epoch20 is 0.02466788039141715
# The validation loss after epoch20 is 0.012583660837842204
# Epoch : 22
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.023223 after 5
# The training loss: 0.025779 after 10
# The training loss: 0.026710 after 15
# The training loss: 0.025852 after 20
# The training loss: 0.025854 after 25
# The training loss: 0.025637 after 30
# The training loss: 0.025153 after 35
# The training loss: 0.026912 after 40
# The training loss: 0.026905 after 45
# The training loss: 0.026375 after 50
# The training loss: 0.025807 after 55
# The training loss: 0.025663 after 60
# The training loss: 0.025484 after 65
# The training loss: 0.025568 after 70
# The training loss: 0.025583 after 75
# The training loss: 0.025916 after 80
# The training loss: 0.026355 after 85
# The training loss: 0.026289 after 90
# The training loss: 0.026211 after 95
# The training loss: 0.025748 after 100
# The training loss: 0.025688 after 105
# The Validation loss: 0.014385 after 5
# The Validation loss: 0.012171 after 10
# The Validation loss: 0.012605 after 15
# The Validation loss: 0.012845 after 20
# The Validation loss: 0.012773 after 25
# The training loss after epoch21 is 0.0256288980952333
# The validation loss after epoch21 is 0.01243191570198053
# Epoch : 23
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.020557 after 5
# The training loss: 0.021769 after 10
# The training loss: 0.023059 after 15
# The training loss: 0.023244 after 20
# The training loss: 0.022822 after 25
# The training loss: 0.022950 after 30
# The training loss: 0.023007 after 35
# The training loss: 0.022899 after 40
# The training loss: 0.023629 after 45
# The training loss: 0.023822 after 50
# The training loss: 0.024707 after 55
# The training loss: 0.024332 after 60
# The training loss: 0.024462 after 65
# The training loss: 0.024660 after 70
# The training loss: 0.024926 after 75
# The training loss: 0.024653 after 80
# The training loss: 0.024670 after 85
# The training loss: 0.024654 after 90
# The training loss: 0.024318 after 95
# The training loss: 0.024033 after 100
# The training loss: 0.023797 after 105
# The Validation loss: 0.012106 after 5
# The Validation loss: 0.013670 after 10
# The Validation loss: 0.013357 after 15
# The Validation loss: 0.013515 after 20
# The Validation loss: 0.012675 after 25
# The training loss after epoch22 is 0.02382321350387096
# The validation loss after epoch22 is 0.012412659479805483
# Epoch : 24
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.021620 after 5
# The training loss: 0.022267 after 10
# The training loss: 0.022308 after 15
# The training loss: 0.025782 after 20
# The training loss: 0.025765 after 25
# The training loss: 0.026155 after 30
# The training loss: 0.026168 after 35
# The training loss: 0.025893 after 40
# The training loss: 0.025874 after 45
# The training loss: 0.025556 after 50
# The training loss: 0.025270 after 55
# The training loss: 0.025446 after 60
# The training loss: 0.024794 after 65
# The training loss: 0.025005 after 70
# The training loss: 0.024319 after 75
# The training loss: 0.024361 after 80
# The training loss: 0.024252 after 85
# The training loss: 0.024197 after 90
# The training loss: 0.024233 after 95
# The training loss: 0.023944 after 100
# The training loss: 0.023634 after 105
# The Validation loss: 0.012360 after 5
# The Validation loss: 0.012179 after 10
# The Validation loss: 0.012125 after 15
# The Validation loss: 0.011510 after 20
# The Validation loss: 0.012308 after 25
# The training loss after epoch23 is 0.023603145127065503
# The validation loss after epoch23 is 0.012048256366700637
# Epoch : 25
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.019531 after 5
# The training loss: 0.018230 after 10
# The training loss: 0.020204 after 15
# The training loss: 0.021281 after 20
# The training loss: 0.021774 after 25
# The training loss: 0.023394 after 30
# The training loss: 0.023306 after 35
# The training loss: 0.023143 after 40
# The training loss: 0.023230 after 45
# The training loss: 0.023643 after 50
# The training loss: 0.023436 after 55
# The training loss: 0.023432 after 60
# The training loss: 0.024008 after 65
# The training loss: 0.024000 after 70
# The training loss: 0.024264 after 75
# The training loss: 0.024402 after 80
# The training loss: 0.024282 after 85
# The training loss: 0.024382 after 90
# The training loss: 0.024846 after 95
# The training loss: 0.024609 after 100
# The training loss: 0.024473 after 105
# The Validation loss: 0.012255 after 5
# The Validation loss: 0.013603 after 10
# The Validation loss: 0.013675 after 15
# The Validation loss: 0.013145 after 20
# The Validation loss: 0.012261 after 25
# The training loss after epoch24 is 0.02445441489192413
# The validation loss after epoch24 is 0.012177316248978678
# Epoch : 26
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.024794 after 5
# The training loss: 0.022315 after 10
# The training loss: 0.023336 after 15
# The training loss: 0.022760 after 20
# The training loss: 0.022551 after 25
# The training loss: 0.022698 after 30
# The training loss: 0.022221 after 35
# The training loss: 0.022681 after 40
# The training loss: 0.023084 after 45
# The training loss: 0.022859 after 50
# The training loss: 0.022642 after 55
# The training loss: 0.022828 after 60
# The training loss: 0.022557 after 65
# The training loss: 0.022731 after 70
# The training loss: 0.023027 after 75
# The training loss: 0.023474 after 80
# The training loss: 0.023318 after 85
# The training loss: 0.023646 after 90
# The training loss: 0.023400 after 95
# The training loss: 0.023753 after 100
# The training loss: 0.023800 after 105
# The Validation loss: 0.010067 after 5
# The Validation loss: 0.012035 after 10
# The Validation loss: 0.013484 after 15
# The Validation loss: 0.012410 after 20
# The Validation loss: 0.012549 after 25
# The training loss after epoch25 is 0.023746197854899415
# The validation loss after epoch25 is 0.012392454239049125
# Epoch : 27
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.024234 after 5
# The training loss: 0.023766 after 10
# The training loss: 0.023631 after 15
# The training loss: 0.022355 after 20
# The training loss: 0.022292 after 25
# The training loss: 0.024599 after 30
# The training loss: 0.024289 after 35
# The training loss: 0.024799 after 40
# The training loss: 0.024303 after 45
# The training loss: 0.024534 after 50
# The training loss: 0.024175 after 55
# The training loss: 0.023614 after 60
# The training loss: 0.023131 after 65
# The training loss: 0.022783 after 70
# The training loss: 0.022722 after 75
# The training loss: 0.022778 after 80
# The training loss: 0.023017 after 85
# The training loss: 0.022989 after 90
# The training loss: 0.023256 after 95
# The training loss: 0.023142 after 100
# The training loss: 0.023165 after 105
# The Validation loss: 0.010210 after 5
# The Validation loss: 0.012964 after 10
# The Validation loss: 0.013469 after 15
# The Validation loss: 0.013343 after 20
# The Validation loss: 0.012368 after 25
# The training loss after epoch26 is 0.023175098182821846
# The validation loss after epoch26 is 0.012024512618049826
# Epoch : 28
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.022999 after 5
# The training loss: 0.022534 after 10
# The training loss: 0.022196 after 15
# The training loss: 0.021181 after 20
# The training loss: 0.020455 after 25
# The training loss: 0.020505 after 30
# The training loss: 0.020943 after 35
# The training loss: 0.021481 after 40
# The training loss: 0.021650 after 45
# The training loss: 0.022374 after 50
# The training loss: 0.023730 after 55
# The training loss: 0.023665 after 60
# The training loss: 0.024084 after 65
# The training loss: 0.024395 after 70
# The training loss: 0.024330 after 75
# The training loss: 0.024619 after 80
# The training loss: 0.024440 after 85
# The training loss: 0.024493 after 90
# The training loss: 0.024252 after 95
# The training loss: 0.024102 after 100
# The training loss: 0.024359 after 105
# The Validation loss: 0.010469 after 5
# The Validation loss: 0.010212 after 10
# The Validation loss: 0.011623 after 15
# The Validation loss: 0.012612 after 20
# The Validation loss: 0.012366 after 25
# The training loss after epoch27 is 0.02431633993509157
# The validation loss after epoch27 is 0.012555876843329313
# Epoch : 29
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.026656 after 5
# The training loss: 0.024157 after 10
# The training loss: 0.022728 after 15
# The training loss: 0.022389 after 20
# The training loss: 0.022228 after 25
# The training loss: 0.021371 after 30
# The training loss: 0.020814 after 35
# The training loss: 0.021128 after 40
# The training loss: 0.021705 after 45
# The training loss: 0.022431 after 50
# The training loss: 0.022986 after 55
# The training loss: 0.023147 after 60
# The training loss: 0.023284 after 65
# The training loss: 0.023192 after 70
# The training loss: 0.023448 after 75
# The training loss: 0.023609 after 80
# The training loss: 0.023522 after 85
# The training loss: 0.023409 after 90
# The training loss: 0.023519 after 95
# The training loss: 0.023417 after 100
# The training loss: 0.023275 after 105
# The Validation loss: 0.010282 after 5
# The Validation loss: 0.013024 after 10
# The Validation loss: 0.013423 after 15
# The Validation loss: 0.012550 after 20
# The Validation loss: 0.012522 after 25
# The training loss after epoch28 is 0.023216605590335497
# The validation loss after epoch28 is 0.01238607867330341
# Epoch : 30
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.019522 after 5
# The training loss: 0.020237 after 10
# The training loss: 0.020320 after 15
# The training loss: 0.020580 after 20
# The training loss: 0.020524 after 25
# The training loss: 0.021105 after 30
# The training loss: 0.021809 after 35
# The training loss: 0.022265 after 40
# The training loss: 0.022321 after 45
# The training loss: 0.022155 after 50
# The training loss: 0.022159 after 55
# The training loss: 0.022435 after 60
# The training loss: 0.022444 after 65
# The training loss: 0.022588 after 70
# The training loss: 0.022957 after 75
# The training loss: 0.022905 after 80
# The training loss: 0.022798 after 85
# The training loss: 0.022704 after 90
# The training loss: 0.023035 after 95
# The training loss: 0.023052 after 100
# The training loss: 0.022919 after 105
# The Validation loss: 0.011241 after 5
# The Validation loss: 0.011523 after 10
# The Validation loss: 0.013086 after 15
# The Validation loss: 0.013119 after 20
# The Validation loss: 0.013047 after 25
# The training loss after epoch29 is 0.023057634854215567
# The validation loss after epoch29 is 0.012654054780033374
# Epoch : 31
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.029169 after 5
# The training loss: 0.027878 after 10
# The training loss: 0.025614 after 15
# The training loss: 0.027242 after 20
# The training loss: 0.025383 after 25
# The training loss: 0.024755 after 30
# The training loss: 0.024467 after 35
# The training loss: 0.025222 after 40
# The training loss: 0.025312 after 45
# The training loss: 0.026016 after 50
# The training loss: 0.025879 after 55
# The training loss: 0.025542 after 60
# The training loss: 0.025271 after 65
# The training loss: 0.025123 after 70
# The training loss: 0.025027 after 75
# The training loss: 0.024541 after 80
# The training loss: 0.024567 after 85
# The training loss: 0.024371 after 90
# The training loss: 0.024476 after 95
# The training loss: 0.024600 after 100
# The training loss: 0.024365 after 105
# The Validation loss: 0.012617 after 5
# The Validation loss: 0.012533 after 10
# The Validation loss: 0.012089 after 15
# The Validation loss: 0.011781 after 20
# The Validation loss: 0.012294 after 25
# The training loss after epoch30 is 0.024385575495700692
# The validation loss after epoch30 is 0.012149146435875358
# Epoch : 32
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.026601 after 5
# The training loss: 0.026929 after 10
# The training loss: 0.026067 after 15
# The training loss: 0.024631 after 20
# The training loss: 0.024234 after 25
# The training loss: 0.024247 after 30
# The training loss: 0.023762 after 35
# The training loss: 0.023094 after 40
# The training loss: 0.023397 after 45
# The training loss: 0.023419 after 50
# The training loss: 0.023050 after 55
# The training loss: 0.023057 after 60
# The training loss: 0.023348 after 65
# The training loss: 0.023359 after 70
# The training loss: 0.023138 after 75
# The training loss: 0.023150 after 80
# The training loss: 0.022658 after 85
# The training loss: 0.022916 after 90
# The training loss: 0.022798 after 95
# The training loss: 0.022540 after 100
# The training loss: 0.022545 after 105
# The Validation loss: 0.009948 after 5
# The Validation loss: 0.009469 after 10
# The Validation loss: 0.009856 after 15
# The Validation loss: 0.010620 after 20
# The Validation loss: 0.011666 after 25
# The training loss after epoch31 is 0.02250410578644503
# The validation loss after epoch31 is 0.011817426609470529
# Epoch : 33
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.020914 after 5
# The training loss: 0.023771 after 10
# The training loss: 0.022676 after 15
# The training loss: 0.022754 after 20
# The training loss: 0.022994 after 25
# The training loss: 0.021906 after 30
# The training loss: 0.021405 after 35
# The training loss: 0.021221 after 40
# The training loss: 0.021072 after 45
# The training loss: 0.021318 after 50
# The training loss: 0.021470 after 55
# The training loss: 0.021621 after 60
# The training loss: 0.021624 after 65
# The training loss: 0.022130 after 70
# The training loss: 0.022000 after 75
# The training loss: 0.022216 after 80
# The training loss: 0.022229 after 85
# The training loss: 0.021960 after 90
# The training loss: 0.022354 after 95
# The training loss: 0.022435 after 100
# The training loss: 0.022353 after 105
# The Validation loss: 0.011987 after 5
# The Validation loss: 0.012661 after 10
# The Validation loss: 0.012921 after 15
# The Validation loss: 0.012843 after 20
# The Validation loss: 0.012436 after 25
# The training loss after epoch32 is 0.022457632689003446
# The validation loss after epoch32 is 0.012201909028506302
# Epoch : 34
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.021117 after 5
# The training loss: 0.024928 after 10
# The training loss: 0.023402 after 15
# The training loss: 0.023546 after 20
# The training loss: 0.023812 after 25
# The training loss: 0.024214 after 30
# The training loss: 0.024233 after 35
# The training loss: 0.024052 after 40
# The training loss: 0.024137 after 45
# The training loss: 0.023836 after 50
# The training loss: 0.023795 after 55
# The training loss: 0.023190 after 60
# The training loss: 0.023355 after 65
# The training loss: 0.023192 after 70
# The training loss: 0.023448 after 75
# The training loss: 0.023408 after 80
# The training loss: 0.023559 after 85
# The training loss: 0.023722 after 90
# The training loss: 0.023450 after 95
# The training loss: 0.023167 after 100
# The training loss: 0.022961 after 105
# The Validation loss: 0.012493 after 5
# The Validation loss: 0.012333 after 10
# The Validation loss: 0.012213 after 15
# The Validation loss: 0.012527 after 20
# The Validation loss: 0.012442 after 25
# The training loss after epoch33 is 0.022902533977402006
# The validation loss after epoch33 is 0.012061299447191426
# Epoch : 35
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.024433 after 5
# The training loss: 0.023205 after 10
# The training loss: 0.023639 after 15
# The training loss: 0.023135 after 20
# The training loss: 0.023331 after 25
# The training loss: 0.024017 after 30
# The training loss: 0.023421 after 35
# The training loss: 0.023376 after 40
# The training loss: 0.022742 after 45
# The training loss: 0.022779 after 50
# The training loss: 0.023635 after 55
# The training loss: 0.023725 after 60
# The training loss: 0.023344 after 65
# The training loss: 0.023365 after 70
# The training loss: 0.022826 after 75
# The training loss: 0.022428 after 80
# The training loss: 0.022307 after 85
# The training loss: 0.022427 after 90
# The training loss: 0.022657 after 95
# The training loss: 0.022941 after 100
# The training loss: 0.022729 after 105
# The Validation loss: 0.011106 after 5
# The Validation loss: 0.013085 after 10
# The Validation loss: 0.013209 after 15
# The Validation loss: 0.012720 after 20
# The Validation loss: 0.012214 after 25
# The training loss after epoch34 is 0.022675731464528597
# The validation loss after epoch34 is 0.011758108436359088
# Epoch : 36
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.024285 after 5
# The training loss: 0.020311 after 10
# The training loss: 0.022881 after 15
# The training loss: 0.022503 after 20
# The training loss: 0.022540 after 25
# The training loss: 0.022471 after 30
# The training loss: 0.021870 after 35
# The training loss: 0.022243 after 40
# The training loss: 0.021952 after 45
# The training loss: 0.021972 after 50
# The training loss: 0.021774 after 55
# The training loss: 0.022012 after 60
# The training loss: 0.022154 after 65
# The training loss: 0.021907 after 70
# The training loss: 0.022014 after 75
# The training loss: 0.022196 after 80
# The training loss: 0.022446 after 85
# The training loss: 0.022463 after 90
# The training loss: 0.022482 after 95
# The training loss: 0.022535 after 100
# The training loss: 0.022234 after 105
# The Validation loss: 0.011438 after 5
# The Validation loss: 0.012488 after 10
# The Validation loss: 0.012142 after 15
# The Validation loss: 0.012115 after 20
# The Validation loss: 0.012826 after 25
# The training loss after epoch35 is 0.02219936830408023
# The validation loss after epoch35 is 0.012458252538834733
# Epoch : 37
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.022899 after 5
# The training loss: 0.023092 after 10
# The training loss: 0.022485 after 15
# The training loss: 0.022144 after 20
# The training loss: 0.024721 after 25
# The training loss: 0.025635 after 30
# The training loss: 0.024753 after 35
# The training loss: 0.023647 after 40
# The training loss: 0.023508 after 45
# The training loss: 0.023405 after 50
# The training loss: 0.023282 after 55
# The training loss: 0.023334 after 60
# The training loss: 0.023242 after 65
# The training loss: 0.023526 after 70
# The training loss: 0.023160 after 75
# The training loss: 0.022728 after 80
# The training loss: 0.022548 after 85
# The training loss: 0.022402 after 90
# The training loss: 0.022311 after 95
# The training loss: 0.022133 after 100
# The training loss: 0.022136 after 105
# The Validation loss: 0.013462 after 5
# The Validation loss: 0.013030 after 10
# The Validation loss: 0.012682 after 15
# The Validation loss: 0.013310 after 20
# The Validation loss: 0.012930 after 25
# The training loss after epoch36 is 0.02218014817669963
# The validation loss after epoch36 is 0.01242047362731775
# Epoch : 38
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.029192 after 5
# The training loss: 0.025556 after 10
# The training loss: 0.028923 after 15
# The training loss: 0.028006 after 20
# The training loss: 0.028045 after 25
# The training loss: 0.028120 after 30
# The training loss: 0.026511 after 35
# The training loss: 0.026312 after 40
# The training loss: 0.026274 after 45
# The training loss: 0.025777 after 50
# The training loss: 0.025111 after 55
# The training loss: 0.024907 after 60
# The training loss: 0.024347 after 65
# The training loss: 0.024011 after 70
# The training loss: 0.023514 after 75
# The training loss: 0.023360 after 80
# The training loss: 0.022991 after 85
# The training loss: 0.022876 after 90
# The training loss: 0.022886 after 95
# The training loss: 0.022856 after 100
# The training loss: 0.022646 after 105
# The Validation loss: 0.012093 after 5
# The Validation loss: 0.010333 after 10
# The Validation loss: 0.010555 after 15
# The Validation loss: 0.011202 after 20
# The Validation loss: 0.012019 after 25
# The training loss after epoch37 is 0.022700134047550495
# The validation loss after epoch37 is 0.011746994378598202
# Epoch : 39
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.017187 after 5
# The training loss: 0.018191 after 10
# The training loss: 0.020962 after 15
# The training loss: 0.020961 after 20
# The training loss: 0.021922 after 25
# The training loss: 0.022146 after 30
# The training loss: 0.021912 after 35
# The training loss: 0.023343 after 40
# The training loss: 0.023789 after 45
# The training loss: 0.023600 after 50
# The training loss: 0.023615 after 55
# The training loss: 0.023934 after 60
# The training loss: 0.023559 after 65
# The training loss: 0.023592 after 70
# The training loss: 0.023401 after 75
# The training loss: 0.023143 after 80
# The training loss: 0.022975 after 85
# The training loss: 0.023156 after 90
# The training loss: 0.023057 after 95
# The training loss: 0.023023 after 100
# The training loss: 0.022666 after 105
# The Validation loss: 0.012438 after 5
# The Validation loss: 0.011698 after 10
# The Validation loss: 0.010527 after 15
# The Validation loss: 0.011752 after 20
# The Validation loss: 0.012040 after 25
# The training loss after epoch38 is 0.02254349021748105
# The validation loss after epoch38 is 0.01162696721051573
# Epoch : 40
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.021014 after 5
# The training loss: 0.022918 after 10
# The training loss: 0.023357 after 15
# The training loss: 0.021539 after 20
# The training loss: 0.021848 after 25
# The training loss: 0.021055 after 30
# The training loss: 0.022148 after 35
# The training loss: 0.022124 after 40
# The training loss: 0.022638 after 45
# The training loss: 0.022135 after 50
# The training loss: 0.021778 after 55
# The training loss: 0.022144 after 60
# The training loss: 0.022056 after 65
# The training loss: 0.021657 after 70
# The training loss: 0.021674 after 75
# The training loss: 0.021787 after 80
# The training loss: 0.021767 after 85
# The training loss: 0.021587 after 90
# The training loss: 0.021530 after 95
# The training loss: 0.021868 after 100
# The training loss: 0.021997 after 105
# The Validation loss: 0.010307 after 5
# The Validation loss: 0.013791 after 10
# The Validation loss: 0.012921 after 15
# The Validation loss: 0.012588 after 20
# The Validation loss: 0.011872 after 25
# The training loss after epoch39 is 0.021939113852046666
# The validation loss after epoch39 is 0.011550967777314668
# Epoch : 41
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.023145 after 5
# The training loss: 0.023224 after 10
# The training loss: 0.023414 after 15
# The training loss: 0.022633 after 20
# The training loss: 0.021600 after 25
# The training loss: 0.021922 after 30
# The training loss: 0.021225 after 35
# The training loss: 0.021351 after 40
# The training loss: 0.021748 after 45
# The training loss: 0.021563 after 50
# The training loss: 0.021161 after 55
# The training loss: 0.021616 after 60
# The training loss: 0.021399 after 65
# The training loss: 0.021674 after 70
# The training loss: 0.021878 after 75
# The training loss: 0.022073 after 80
# The training loss: 0.021794 after 85
# The training loss: 0.021823 after 90
# The training loss: 0.021970 after 95
# The training loss: 0.021802 after 100
# The training loss: 0.021819 after 105
# The Validation loss: 0.010491 after 5
# The Validation loss: 0.012188 after 10
# The Validation loss: 0.011585 after 15
# The Validation loss: 0.010846 after 20
# The Validation loss: 0.011221 after 25
# The training loss after epoch40 is 0.021754157043082124
# The validation loss after epoch40 is 0.010790560520925576
# Epoch : 42
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.022495 after 5
# The training loss: 0.022319 after 10
# The training loss: 0.023791 after 15
# The training loss: 0.024270 after 20
# The training loss: 0.023100 after 25
# The training loss: 0.022132 after 30
# The training loss: 0.023230 after 35
# The training loss: 0.022488 after 40
# The training loss: 0.023430 after 45
# The training loss: 0.023763 after 50
# The training loss: 0.023242 after 55
# The training loss: 0.023295 after 60
# The training loss: 0.023225 after 65
# The training loss: 0.023024 after 70
# The training loss: 0.022686 after 75
# The training loss: 0.022214 after 80
# The training loss: 0.022164 after 85
# The training loss: 0.021793 after 90
# The training loss: 0.021636 after 95
# The training loss: 0.021898 after 100
# The training loss: 0.022004 after 105
# The Validation loss: 0.011721 after 5
# The Validation loss: 0.011502 after 10
# The Validation loss: 0.010836 after 15
# The Validation loss: 0.011339 after 20
# The Validation loss: 0.012022 after 25
# The training loss after epoch41 is 0.021916999728112688
# The validation loss after epoch41 is 0.011470997003833154
# Epoch : 43
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.018298 after 5
# The training loss: 0.019183 after 10
# The training loss: 0.021361 after 15
# The training loss: 0.021456 after 20
# The training loss: 0.020881 after 25
# The training loss: 0.021204 after 30
# The training loss: 0.021269 after 35
# The training loss: 0.021131 after 40
# The training loss: 0.020540 after 45
# The training loss: 0.020836 after 50
# The training loss: 0.020616 after 55
# The training loss: 0.020647 after 60
# The training loss: 0.020590 after 65
# The training loss: 0.021012 after 70
# The training loss: 0.020606 after 75
# The training loss: 0.020591 after 80
# The training loss: 0.020339 after 85
# The training loss: 0.020478 after 90
# The training loss: 0.020764 after 95
# The training loss: 0.021080 after 100
# The training loss: 0.021168 after 105
# The Validation loss: 0.008692 after 5
# The Validation loss: 0.010603 after 10
# The Validation loss: 0.010380 after 15
# The Validation loss: 0.011072 after 20
# The Validation loss: 0.012053 after 25
# The training loss after epoch42 is 0.021253500213649457
# The validation loss after epoch42 is 0.011658707175414368
# Epoch : 44
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.019317 after 5
# The training loss: 0.021793 after 10
# The training loss: 0.019154 after 15
# The training loss: 0.019769 after 20
# The training loss: 0.019357 after 25
# The training loss: 0.020046 after 30
# The training loss: 0.020268 after 35
# The training loss: 0.021363 after 40
# The training loss: 0.021163 after 45
# The training loss: 0.020855 after 50
# The training loss: 0.020617 after 55
# The training loss: 0.020949 after 60
# The training loss: 0.020781 after 65
# The training loss: 0.021156 after 70
# The training loss: 0.021344 after 75
# The training loss: 0.021424 after 80
# The training loss: 0.022054 after 85
# The training loss: 0.022311 after 90
# The training loss: 0.022328 after 95
# The training loss: 0.022242 after 100
# The training loss: 0.022029 after 105
# The Validation loss: 0.015092 after 5
# The Validation loss: 0.013000 after 10
# The Validation loss: 0.012417 after 15
# The Validation loss: 0.012290 after 20
# The Validation loss: 0.011557 after 25
# The training loss after epoch43 is 0.02205902786502685
# The validation loss after epoch43 is 0.011303838812917275
# Epoch : 45
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.034256 after 5
# The training loss: 0.025567 after 10
# The training loss: 0.024954 after 15
# The training loss: 0.025237 after 20
# The training loss: 0.024369 after 25
# The training loss: 0.023446 after 30
# The training loss: 0.023124 after 35
# The training loss: 0.023002 after 40
# The training loss: 0.022721 after 45
# The training loss: 0.022546 after 50
# The training loss: 0.022485 after 55
# The training loss: 0.022230 after 60
# The training loss: 0.022394 after 65
# The training loss: 0.022085 after 70
# The training loss: 0.022145 after 75
# The training loss: 0.022127 after 80
# The training loss: 0.022442 after 85
# The training loss: 0.022287 after 90
# The training loss: 0.022084 after 95
# The training loss: 0.022013 after 100
# The training loss: 0.022160 after 105
# The Validation loss: 0.011936 after 5
# The Validation loss: 0.011972 after 10
# The Validation loss: 0.012739 after 15
# The Validation loss: 0.012381 after 20
# The Validation loss: 0.012108 after 25
# The training loss after epoch44 is 0.022072083212043663
# The validation loss after epoch44 is 0.011644109620113176
# Epoch : 46
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.019765 after 5
# The training loss: 0.024039 after 10
# The training loss: 0.022112 after 15
# The training loss: 0.022927 after 20
# The training loss: 0.022518 after 25
# The training loss: 0.021398 after 30
# The training loss: 0.021258 after 35
# The training loss: 0.021995 after 40
# The training loss: 0.021609 after 45
# The training loss: 0.021197 after 50
# The training loss: 0.020948 after 55
# The training loss: 0.020959 after 60
# The training loss: 0.021380 after 65
# The training loss: 0.021241 after 70
# The training loss: 0.021144 after 75
# The training loss: 0.021111 after 80
# The training loss: 0.021124 after 85
# The training loss: 0.021327 after 90
# The training loss: 0.021537 after 95
# The training loss: 0.021481 after 100
# The training loss: 0.021446 after 105
# The Validation loss: 0.010637 after 5
# The Validation loss: 0.011392 after 10
# The Validation loss: 0.012821 after 15
# The Validation loss: 0.013084 after 20
# The Validation loss: 0.012922 after 25
# The training loss after epoch45 is 0.02153016723413218
# The validation loss after epoch45 is 0.012383165485756674
# Epoch : 47
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.017827 after 5
# The training loss: 0.018889 after 10
# The training loss: 0.018506 after 15
# The training loss: 0.020468 after 20
# The training loss: 0.021313 after 25
# The training loss: 0.020731 after 30
# The training loss: 0.020694 after 35
# The training loss: 0.020830 after 40
# The training loss: 0.020646 after 45
# The training loss: 0.021366 after 50
# The training loss: 0.021286 after 55
# The training loss: 0.021994 after 60
# The training loss: 0.022093 after 65
# The training loss: 0.021891 after 70
# The training loss: 0.021550 after 75
# The training loss: 0.021572 after 80
# The training loss: 0.021302 after 85
# The training loss: 0.021340 after 90
# The training loss: 0.021363 after 95
# The training loss: 0.021239 after 100
# The training loss: 0.021219 after 105
# The Validation loss: 0.012231 after 5
# The Validation loss: 0.010151 after 10
# The Validation loss: 0.011129 after 15
# The Validation loss: 0.010856 after 20
# The Validation loss: 0.012290 after 25
# The training loss after epoch46 is 0.021302858457555755
# The validation loss after epoch46 is 0.012282400877407203
# Epoch : 48
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.016288 after 5
# The training loss: 0.019388 after 10
# The training loss: 0.023389 after 15
# The training loss: 0.023295 after 20
# The training loss: 0.023881 after 25
# The training loss: 0.023361 after 30
# The training loss: 0.023162 after 35
# The training loss: 0.023043 after 40
# The training loss: 0.022360 after 45
# The training loss: 0.021987 after 50
# The training loss: 0.021556 after 55
# The training loss: 0.021461 after 60
# The training loss: 0.021322 after 65
# The training loss: 0.021136 after 70
# The training loss: 0.021376 after 75
# The training loss: 0.021100 after 80
# The training loss: 0.021099 after 85
# The training loss: 0.021185 after 90
# The training loss: 0.021096 after 95
# The training loss: 0.020960 after 100
# The training loss: 0.020873 after 105
# The Validation loss: 0.012753 after 5
# The Validation loss: 0.013218 after 10
# The Validation loss: 0.012446 after 15
# The Validation loss: 0.012409 after 20
# The Validation loss: 0.012035 after 25
# The training loss after epoch47 is 0.02082921144902186
# The validation loss after epoch47 is 0.01176307957468451
# Epoch : 49
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.023122 after 5
# The training loss: 0.019971 after 10
# The training loss: 0.018893 after 15
# The training loss: 0.018752 after 20
# The training loss: 0.020168 after 25
# The training loss: 0.021197 after 30
# The training loss: 0.021336 after 35
# The training loss: 0.021413 after 40
# The training loss: 0.021239 after 45
# The training loss: 0.020595 after 50
# The training loss: 0.020963 after 55
# The training loss: 0.020949 after 60
# The training loss: 0.021271 after 65
# The training loss: 0.021477 after 70
# The training loss: 0.021505 after 75
# The training loss: 0.021703 after 80
# The training loss: 0.021605 after 85
# The training loss: 0.021503 after 90
# The training loss: 0.021436 after 95
# The training loss: 0.021303 after 100
# The training loss: 0.021244 after 105
# The Validation loss: 0.012026 after 5
# The Validation loss: 0.010810 after 10
# The Validation loss: 0.011460 after 15
# The Validation loss: 0.011299 after 20
# The Validation loss: 0.011938 after 25
# The training loss after epoch48 is 0.02117924490118684
# The validation loss after epoch48 is 0.011993934225701814
# Epoch : 50
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# The training loss: 0.018037 after 5
# The training loss: 0.021106 after 10
# The training loss: 0.020064 after 15
# The training loss: 0.020588 after 20
# The training loss: 0.019432 after 25
# The training loss: 0.019704 after 30
# The training loss: 0.019430 after 35
# The training loss: 0.020112 after 40
# The training loss: 0.019861 after 45
# The training loss: 0.020143 after 50
# The training loss: 0.020145 after 55
# The training loss: 0.020372 after 60
# The training loss: 0.020724 after 65
# The training loss: 0.020369 after 70
# The training loss: 0.020286 after 75
# The training loss: 0.020045 after 80
# The training loss: 0.020138 after 85
# The training loss: 0.020059 after 90
# The training loss: 0.020237 after 95
# The training loss: 0.020241 after 100
# The training loss: 0.020468 after 105
# The Validation loss: 0.012106 after 5
# The Validation loss: 0.011433 after 10
# The Validation loss: 0.011556 after 15
# The Validation loss: 0.011575 after 20
# The Validation loss: 0.012128 after 25
# The training loss after epoch49 is 0.020404787386907822
# The validation loss after epoch49 is 0.011654558602955745

# %%
min_value = min(training_loss)
min_index = training_loss.index(min_value)
print(min_value)
print(min_index)
print(len(training_loss))
# Out:
# 0.020404787386907822
# 49
# 50

# %%
min_value = min(validation_loss)
min_index = validation_loss.index(min_value)
print(min_value)
print(min_index)
print(len(validation_loss))
# Out:
# 0.010790560520925576
# 40
# 50

# %%
plt.figure(figsize = (18,8))
plt.rcParams['axes.facecolor'] = 'black'
plt.grid(False)
plt.title("Loss vs Epoch")
plt.xlabel("Number of Epoch")
plt.ylabel("Loss")
labels = ['Training Loss', 'Validation Loss']
plt.plot(training_loss, 'w:', label= labels[0], linewidth=2)
plt.plot(validation_loss,'r', label=labels[1])
plt.legend()
plt.show()
